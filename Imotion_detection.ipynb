# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
import os
from matplotlib import pyplot as plt
import numpy as np

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
batch_size = 32

# %%
train_data_dir = '../data/train'
validation_data_dir = '../data/test'
#https://www.kaggle.com/datasets/msambare/fer2013

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    color_mode='grayscale',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size = batch_size,
    class_mode = 'categorical',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    color_mode='grayscale',
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
class_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
img , label = train_generator.__next__()

# %%
import random
i = random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam' , loss='categorical_crossentropy' , metrics=['accuracy'])
print(model.summary())
# Out:
# c:\Users\acsen\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 44, 44, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 20, 20, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,489,095 (9.50 MB)
#  Trainable params: 2,489,095 (9.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_path = 'data/train'
test_path = 'data/test'

num_train_imgs = 0
for root,dirs,files in os.walk(train_path):
    num_train_imgs += len(files)

num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)

epochs =50

history = model.fit(train_generator,
                    steps_per_epoch = num_train_imgs //batch_size,
                    epochs=epochs,
                    validation_data = validation_generator,
                    validation_steps=num_test_imgs//batch_size)

model.save('emotion_detection_model_100epochs.h5')
# Out:
# Epoch 1/50
# c:\Users\acsen\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 269s 295ms/step - accuracy: 0.2576 - loss: 1.7997 - val_accuracy: 0.3392 - val_loss: 1.6692
# Epoch 2/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 108s 119ms/step - accuracy: 0.3078 - loss: 1.6979 - val_accuracy: 0.4206 - val_loss: 1.5000
# Epoch 3/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 127s 141ms/step - accuracy: 0.3852 - loss: 1.5656 - val_accuracy: 0.4717 - val_loss: 1.3756
# Epoch 4/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 140s 155ms/step - accuracy: 0.4306 - loss: 1.4633 - val_accuracy: 0.5086 - val_loss: 1.2839
# Epoch 5/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.4658 - loss: 1.3869 - val_accuracy: 0.5267 - val_loss: 1.2371
# Epoch 6/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 69s 77ms/step - accuracy: 0.4773 - loss: 1.3564 - val_accuracy: 0.5417 - val_loss: 1.2014
# Epoch 7/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 71s 79ms/step - accuracy: 0.4917 - loss: 1.3167 - val_accuracy: 0.5433 - val_loss: 1.1857
# Epoch 8/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 71s 79ms/step - accuracy: 0.5081 - loss: 1.2837 - val_accuracy: 0.5596 - val_loss: 1.1631
# Epoch 9/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 70s 78ms/step - accuracy: 0.5161 - loss: 1.2630 - val_accuracy: 0.5639 - val_loss: 1.1468
# Epoch 10/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 71s 79ms/step - accuracy: 0.5198 - loss: 1.2595 - val_accuracy: 0.5306 - val_loss: 1.2335
# Epoch 11/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.5293 - loss: 1.2452 - val_accuracy: 0.5706 - val_loss: 1.1208
# Epoch 12/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 71s 79ms/step - accuracy: 0.5374 - loss: 1.2305 - val_accuracy: 0.5648 - val_loss: 1.1314
# Epoch 13/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 71s 79ms/step - accuracy: 0.5338 - loss: 1.2223 - val_accuracy: 0.5761 - val_loss: 1.1206
# Epoch 14/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.5466 - loss: 1.1940 - val_accuracy: 0.5726 - val_loss: 1.1136
# Epoch 15/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.5518 - loss: 1.2004 - val_accuracy: 0.5688 - val_loss: 1.1251
# Epoch 16/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.5489 - loss: 1.1916 - val_accuracy: 0.5762 - val_loss: 1.1022
# Epoch 17/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.5549 - loss: 1.1741 - val_accuracy: 0.5847 - val_loss: 1.0954
# Epoch 18/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 136s 151ms/step - accuracy: 0.5556 - loss: 1.1716 - val_accuracy: 0.5885 - val_loss: 1.0955
# Epoch 19/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 155s 172ms/step - accuracy: 0.5553 - loss: 1.1721 - val_accuracy: 0.5899 - val_loss: 1.0924
# Epoch 20/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.5602 - loss: 1.1572 - val_accuracy: 0.5918 - val_loss: 1.0838
# Epoch 21/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 72s 80ms/step - accuracy: 0.5602 - loss: 1.1586 - val_accuracy: 0.5855 - val_loss: 1.0950
# Epoch 22/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - accuracy: 0.5641 - loss: 1.1517 - val_accuracy: 0.5971 - val_loss: 1.0705
# Epoch 23/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5598 - loss: 1.1446 - val_accuracy: 0.5954 - val_loss: 1.0769
# Epoch 24/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.5652 - loss: 1.1440 - val_accuracy: 0.5971 - val_loss: 1.0757
# Epoch 25/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.5708 - loss: 1.1395 - val_accuracy: 0.5929 - val_loss: 1.0699
# Epoch 26/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5690 - loss: 1.1444 - val_accuracy: 0.6014 - val_loss: 1.0620
# Epoch 27/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5730 - loss: 1.1237 - val_accuracy: 0.5985 - val_loss: 1.0717
# Epoch 28/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.5691 - loss: 1.1328 - val_accuracy: 0.5989 - val_loss: 1.0632
# Epoch 29/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - accuracy: 0.5782 - loss: 1.1162 - val_accuracy: 0.5986 - val_loss: 1.0599
# Epoch 30/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.5793 - loss: 1.1127 - val_accuracy: 0.5922 - val_loss: 1.0663
# Epoch 31/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 73s 82ms/step - accuracy: 0.5798 - loss: 1.1242 - val_accuracy: 0.6048 - val_loss: 1.0432
# Epoch 32/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 79s 88ms/step - accuracy: 0.5807 - loss: 1.1105 - val_accuracy: 0.6011 - val_loss: 1.0503
# Epoch 33/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 77s 86ms/step - accuracy: 0.5780 - loss: 1.1151 - val_accuracy: 0.5915 - val_loss: 1.0687
# Epoch 34/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 77s 85ms/step - accuracy: 0.5782 - loss: 1.1026 - val_accuracy: 0.5921 - val_loss: 1.0672
# Epoch 35/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 76s 84ms/step - accuracy: 0.5815 - loss: 1.1014 - val_accuracy: 0.6062 - val_loss: 1.0558
# Epoch 36/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 76s 84ms/step - accuracy: 0.5841 - loss: 1.0945 - val_accuracy: 0.6045 - val_loss: 1.0580
# Epoch 37/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 79s 88ms/step - accuracy: 0.5865 - loss: 1.0956 - val_accuracy: 0.6035 - val_loss: 1.0542
# Epoch 38/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 143s 159ms/step - accuracy: 0.5858 - loss: 1.0947 - val_accuracy: 0.6096 - val_loss: 1.0467
# Epoch 39/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 194s 214ms/step - accuracy: 0.5898 - loss: 1.0857 - val_accuracy: 0.6082 - val_loss: 1.0351
# Epoch 40/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 72s 80ms/step - accuracy: 0.5935 - loss: 1.0788 - val_accuracy: 0.6105 - val_loss: 1.0503
# Epoch 41/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 68s 76ms/step - accuracy: 0.5917 - loss: 1.0932 - val_accuracy: 0.6066 - val_loss: 1.0502
# Epoch 42/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 69s 76ms/step - accuracy: 0.5865 - loss: 1.0940 - val_accuracy: 0.6088 - val_loss: 1.0667
# Epoch 43/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 68s 76ms/step - accuracy: 0.5852 - loss: 1.0901 - val_accuracy: 0.6158 - val_loss: 1.0293
# Epoch 44/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 68s 76ms/step - accuracy: 0.5985 - loss: 1.0747 - val_accuracy: 0.6151 - val_loss: 1.0447
# Epoch 45/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 126s 140ms/step - accuracy: 0.5887 - loss: 1.0875 - val_accuracy: 0.6034 - val_loss: 1.0526
# Epoch 46/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 181s 200ms/step - accuracy: 0.5950 - loss: 1.0703 - val_accuracy: 0.6020 - val_loss: 1.0584
# Epoch 47/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 78s 87ms/step - accuracy: 0.5876 - loss: 1.0851 - val_accuracy: 0.6137 - val_loss: 1.0397
# Epoch 48/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 78s 87ms/step - accuracy: 0.6018 - loss: 1.0603 - val_accuracy: 0.6187 - val_loss: 1.0316
# Epoch 49/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 77s 86ms/step - accuracy: 0.5962 - loss: 1.0622 - val_accuracy: 0.6134 - val_loss: 1.0280
# Epoch 50/50
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 248s 276ms/step - accuracy: 0.5958 - loss: 1.0728 - val_accuracy: 0.6204 - val_loss: 1.0231
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1 , len(loss) +1)
plt.plot(epochs ,loss ,'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from keras.models import load_model

my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

test_img, test_lbl = validation_generator.__next__()
predictions = my_model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy", metrics.accuracy_score(test_labels, predictions))

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Accuracy 0.75

# %%
import random

n = random.randint(0, test_img.shape[0]  -1 )
image = test_img[n]
orig_labl  = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title('Original label is: '+orig_labl+" predicted is: "+pred_labl)
plt.show()
